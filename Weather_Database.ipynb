# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. Set coordinate size to 200.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Checking coordinate length
len(coordinates)
# Out:
# 2000

# %%
# Use the citypy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Condition": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | dalbandin
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | belomorsk
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | cidreira
# Processing Record 8 of Set 1 | yumen
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | hualmay
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | severo-kurilsk
# Processing Record 15 of Set 1 | khandyga
# Processing Record 16 of Set 1 | roma
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | aksha
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | port lincoln
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | saint anthony
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | sagua la grande
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | stornoway
# Processing Record 30 of Set 1 | karratha
# Processing Record 31 of Set 1 | poya
# Processing Record 32 of Set 1 | praia da vitoria
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 1 | ust-nera
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | fayaoue
# Processing Record 41 of Set 1 | sterling
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | el coyote
# Processing Record 44 of Set 1 | beringovskiy
# Processing Record 45 of Set 1 | svetlogorsk
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | eureka
# Processing Record 48 of Set 1 | tahe
# Processing Record 49 of Set 1 | kirkuk
# Processing Record 50 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | lompoc
# Processing Record 5 of Set 2 | mount pleasant
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | grandview
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | kodiak
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | flin flon
# Processing Record 12 of Set 2 | lavrentiya
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 2 | isangel
# Processing Record 22 of Set 2 | blitar
# Processing Record 23 of Set 2 | quatre cocos
# Processing Record 24 of Set 2 | port blair
# Processing Record 25 of Set 2 | saint-georges
# Processing Record 26 of Set 2 | taonan
# Processing Record 27 of Set 2 | ous
# Processing Record 28 of Set 2 | padang
# Processing Record 29 of Set 2 | santa cruz
# Processing Record 30 of Set 2 | pangnirtung
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | saint-philippe
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | ingham
# Processing Record 36 of Set 2 | sept-iles
# Processing Record 37 of Set 2 | otavi
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | rehoboth
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 2 | myitkyina
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | new norfolk
# Processing Record 46 of Set 2 | horta
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | sobolevo
# Processing Record 50 of Set 2 | weyburn
# Processing Record 1 of Set 3 | comodoro rivadavia
# Processing Record 2 of Set 3 | campo gobierno
# Processing Record 3 of Set 3 | teguise
# Processing Record 4 of Set 3 | progreso
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | ormara
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | kibre mengist
# Processing Record 9 of Set 3 | carroll
# Processing Record 10 of Set 3 | vossevangen
# Processing Record 11 of Set 3 | souillac
# Processing Record 12 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | cabulohan
# City not found. Skipping...
# Processing Record 15 of Set 3 | rock sound
# Processing Record 16 of Set 3 | rudbar
# Processing Record 17 of Set 3 | norman wells
# Processing Record 18 of Set 3 | kiunga
# Processing Record 19 of Set 3 | broome
# Processing Record 20 of Set 3 | ugoofaaru
# Processing Record 21 of Set 3 | nouadhibou
# Processing Record 22 of Set 3 | mackenzie
# Processing Record 23 of Set 3 | meulaboh
# Processing Record 24 of Set 3 | udachnyy
# Processing Record 25 of Set 3 | pauini
# Processing Record 26 of Set 3 | fairbanks
# Processing Record 27 of Set 3 | banda aceh
# Processing Record 28 of Set 3 | kholm
# Processing Record 29 of Set 3 | terrace bay
# Processing Record 30 of Set 3 | mount gambier
# Processing Record 31 of Set 3 | zambezi
# Processing Record 32 of Set 3 | baruun-urt
# Processing Record 33 of Set 3 | dieppe
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | ganzhou
# Processing Record 36 of Set 3 | javanrud
# Processing Record 37 of Set 3 | cayenne
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | huarmey
# Processing Record 40 of Set 3 | bronnoysund
# Processing Record 41 of Set 3 | qianguo
# Processing Record 42 of Set 3 | mount isa
# Processing Record 43 of Set 3 | anju
# Processing Record 44 of Set 3 | opuwo
# Processing Record 45 of Set 3 | baie-comeau
# Processing Record 46 of Set 3 | cockburn town
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | houma
# Processing Record 50 of Set 3 | nara
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | camana
# Processing Record 4 of Set 4 | skorodnoye
# Processing Record 5 of Set 4 | dunedin
# Processing Record 6 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 7 of Set 4 | veraval
# Processing Record 8 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 4 | iquique
# Processing Record 10 of Set 4 | valdivia
# Processing Record 11 of Set 4 | ailigandi
# Processing Record 12 of Set 4 | marabba
# Processing Record 13 of Set 4 | limon
# Processing Record 14 of Set 4 | mlonggo
# Processing Record 15 of Set 4 | gat
# Processing Record 16 of Set 4 | qasigiannguit
# Processing Record 17 of Set 4 | tasiilaq
# Processing Record 18 of Set 4 | kendari
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | melfi
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | palana
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | san rafael
# Processing Record 27 of Set 4 | rudnogorsk
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | vandra
# Processing Record 31 of Set 4 | leninsk
# Processing Record 32 of Set 4 | axim
# Processing Record 33 of Set 4 | banmo
# City not found. Skipping...
# Processing Record 34 of Set 4 | dikson
# Processing Record 35 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | mongar
# Processing Record 39 of Set 4 | bassar
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | takoradi
# Processing Record 43 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 4 | nanzhang
# Processing Record 45 of Set 4 | zhigansk
# Processing Record 46 of Set 4 | catarman
# Processing Record 47 of Set 4 | oliveira do hospital
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | tabou
# Processing Record 50 of Set 4 | san carlos de bariloche
# Processing Record 1 of Set 5 | warrnambool
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | nikolskoye
# Processing Record 4 of Set 5 | hobart
# Processing Record 5 of Set 5 | puerto ayora
# Processing Record 6 of Set 5 | ciudad ojeda
# Processing Record 7 of Set 5 | lermontovka
# Processing Record 8 of Set 5 | kavaratti
# Processing Record 9 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 5 | lorengau
# Processing Record 11 of Set 5 | lulea
# Processing Record 12 of Set 5 | coihaique
# Processing Record 13 of Set 5 | mehamn
# Processing Record 14 of Set 5 | diffa
# Processing Record 15 of Set 5 | beloha
# Processing Record 16 of Set 5 | chokurdakh
# Processing Record 17 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 5 | manjacaze
# Processing Record 19 of Set 5 | pacific grove
# Processing Record 20 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 21 of Set 5 | barcelos
# Processing Record 22 of Set 5 | dickson
# Processing Record 23 of Set 5 | sabara
# Processing Record 24 of Set 5 | zemio
# Processing Record 25 of Set 5 | mount vernon
# Processing Record 26 of Set 5 | najran
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | gamba
# Processing Record 29 of Set 5 | upernavik
# Processing Record 30 of Set 5 | zaranj
# Processing Record 31 of Set 5 | tiarei
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | arraial do cabo
# Processing Record 36 of Set 5 | sheridan
# Processing Record 37 of Set 5 | porterville
# Processing Record 38 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 5 | cabo san lucas
# Processing Record 40 of Set 5 | san luis
# Processing Record 41 of Set 5 | imeni poliny osipenko
# Processing Record 42 of Set 5 | el alto
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | boyolangu
# Processing Record 45 of Set 5 | hamilton
# Processing Record 46 of Set 5 | kyra
# Processing Record 47 of Set 5 | vao
# Processing Record 48 of Set 5 | zhangjiakou
# Processing Record 49 of Set 5 | amparai
# City not found. Skipping...
# Processing Record 50 of Set 5 | svetlyy
# Processing Record 1 of Set 6 | birao
# Processing Record 2 of Set 6 | maceio
# Processing Record 3 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 6 | tshikapa
# Processing Record 5 of Set 6 | honavar
# Processing Record 6 of Set 6 | pak phanang
# Processing Record 7 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | ninghai
# Processing Record 9 of Set 6 | ambilobe
# Processing Record 10 of Set 6 | bathsheba
# Processing Record 11 of Set 6 | guerrero negro
# Processing Record 12 of Set 6 | muroto
# Processing Record 13 of Set 6 | haines junction
# Processing Record 14 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 15 of Set 6 | zhezkazgan
# Processing Record 16 of Set 6 | moindou
# Processing Record 17 of Set 6 | fukue
# Processing Record 18 of Set 6 | ponnani
# Processing Record 19 of Set 6 | sutysky
# Processing Record 20 of Set 6 | acapulco
# Processing Record 21 of Set 6 | kamina
# Processing Record 22 of Set 6 | yulara
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | taganak
# Processing Record 25 of Set 6 | enkoping
# Processing Record 26 of Set 6 | arona
# Processing Record 27 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 6 | illapel
# Processing Record 29 of Set 6 | inirida
# Processing Record 30 of Set 6 | laramie
# Processing Record 31 of Set 6 | teahupoo
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | buala
# Processing Record 34 of Set 6 | newport
# Processing Record 35 of Set 6 | pimentel
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | mama
# Processing Record 38 of Set 6 | pontes e lacerda
# Processing Record 39 of Set 6 | tunxi
# City not found. Skipping...
# Processing Record 40 of Set 6 | abomey
# Processing Record 41 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 6 | katherine
# Processing Record 43 of Set 6 | yarovoye
# Processing Record 44 of Set 6 | trogir
# Processing Record 45 of Set 6 | manvi
# Processing Record 46 of Set 6 | montlucon
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | ulaanbaatar
# Processing Record 49 of Set 6 | poplar bluff
# Processing Record 50 of Set 6 | narsaq
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | manacapuru
# Processing Record 3 of Set 7 | xianyang
# Processing Record 4 of Set 7 | yar-sale
# Processing Record 5 of Set 7 | nhulunbuy
# Processing Record 6 of Set 7 | nanga eboko
# Processing Record 7 of Set 7 | conceicao do rio verde
# Processing Record 8 of Set 7 | bose
# Processing Record 9 of Set 7 | srednekolymsk
# Processing Record 10 of Set 7 | pipar
# Processing Record 11 of Set 7 | kidal
# Processing Record 12 of Set 7 | ahipara
# Processing Record 13 of Set 7 | vysokogornyy
# Processing Record 14 of Set 7 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 15 of Set 7 | shubarshi
# Processing Record 16 of Set 7 | mathathane
# Processing Record 17 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 18 of Set 7 | ustyuzhna
# Processing Record 19 of Set 7 | aklavik
# Processing Record 20 of Set 7 | pyaozerskiy
# Processing Record 21 of Set 7 | la romana
# Processing Record 22 of Set 7 | pleshanovo
# Processing Record 23 of Set 7 | kaeo
# Processing Record 24 of Set 7 | dingli
# Processing Record 25 of Set 7 | bardiyah
# Processing Record 26 of Set 7 | la libertad
# Processing Record 27 of Set 7 | marovoay
# Processing Record 28 of Set 7 | mangan
# Processing Record 29 of Set 7 | severnyy-kospashskiy
# Processing Record 30 of Set 7 | sanchursk
# Processing Record 31 of Set 7 | kavieng
# Processing Record 32 of Set 7 | inegol
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | ahuimanu
# Processing Record 35 of Set 7 | carballo
# Processing Record 36 of Set 7 | oktyabrskoye
# Processing Record 37 of Set 7 | altus
# Processing Record 38 of Set 7 | valparaiso
# Processing Record 39 of Set 7 | dingle
# Processing Record 40 of Set 7 | sorland
# Processing Record 41 of Set 7 | la macarena
# Processing Record 42 of Set 7 | mocuba
# Processing Record 43 of Set 7 | manaus
# Processing Record 44 of Set 7 | xihe
# Processing Record 45 of Set 7 | tieling
# Processing Record 46 of Set 7 | esperance
# Processing Record 47 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 48 of Set 7 | leningradskiy
# Processing Record 49 of Set 7 | holme
# Processing Record 50 of Set 7 | linqiong
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | pisco
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | bruck an der leitha
# Processing Record 5 of Set 8 | yagodnoye
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | maicao
# Processing Record 8 of Set 8 | pitimbu
# Processing Record 9 of Set 8 | codrington
# Processing Record 10 of Set 8 | kruisfontein
# Processing Record 11 of Set 8 | voh
# Processing Record 12 of Set 8 | saint-pierre
# Processing Record 13 of Set 8 | la grande
# Processing Record 14 of Set 8 | vila velha
# Processing Record 15 of Set 8 | ajdabiya
# Processing Record 16 of Set 8 | landau
# Processing Record 17 of Set 8 | tecoanapa
# Processing Record 18 of Set 8 | inta
# Processing Record 19 of Set 8 | chara
# Processing Record 20 of Set 8 | ust-kuyga
# Processing Record 21 of Set 8 | gravdal
# Processing Record 22 of Set 8 | kuminskiy
# Processing Record 23 of Set 8 | gewane
# Processing Record 24 of Set 8 | abnub
# Processing Record 25 of Set 8 | aguililla
# Processing Record 26 of Set 8 | bowen
# Processing Record 27 of Set 8 | sao joao da barra
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | halifax
# Processing Record 30 of Set 8 | yatou
# Processing Record 31 of Set 8 | ilulissat
# Processing Record 32 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 33 of Set 8 | rabat
# Processing Record 34 of Set 8 | venado tuerto
# Processing Record 35 of Set 8 | la reforma
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | luanda
# Processing Record 38 of Set 8 | angoche
# Processing Record 39 of Set 8 | dumas
# Processing Record 40 of Set 8 | grindavik
# Processing Record 41 of Set 8 | huhi
# Processing Record 42 of Set 8 | hami
# Processing Record 43 of Set 8 | lar
# Processing Record 44 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 8 | saint-leu
# Processing Record 47 of Set 8 | darhan
# Processing Record 48 of Set 8 | sechura
# Processing Record 49 of Set 8 | dongsheng
# Processing Record 50 of Set 8 | salinopolis
# Processing Record 1 of Set 9 | nzega
# Processing Record 2 of Set 9 | centerville
# Processing Record 3 of Set 9 | frei paulo
# Processing Record 4 of Set 9 | darnah
# Processing Record 5 of Set 9 | atar
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | marsh harbour
# Processing Record 8 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 9 | klaksvik
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | taltal
# Processing Record 12 of Set 9 | puerto baquerizo moreno
# Processing Record 13 of Set 9 | half moon bay
# Processing Record 14 of Set 9 | havre-saint-pierre
# Processing Record 15 of Set 9 | san patricio
# Processing Record 16 of Set 9 | alexandria
# Processing Record 17 of Set 9 | khilok
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | maputo
# Processing Record 20 of Set 9 | marzuq
# Processing Record 21 of Set 9 | berdigestyakh
# Processing Record 22 of Set 9 | nome
# Processing Record 23 of Set 9 | sidney
# Processing Record 24 of Set 9 | nongstoin
# Processing Record 25 of Set 9 | faya
# Processing Record 26 of Set 9 | miquelon
# Processing Record 27 of Set 9 | le port
# Processing Record 28 of Set 9 | saint-joseph
# Processing Record 29 of Set 9 | port hardy
# Processing Record 30 of Set 9 | araouane
# Processing Record 31 of Set 9 | nelson bay
# Processing Record 32 of Set 9 | ocean city
# Processing Record 33 of Set 9 | urumqi
# Processing Record 34 of Set 9 | charters towers
# Processing Record 35 of Set 9 | pingshan
# Processing Record 36 of Set 9 | anito
# Processing Record 37 of Set 9 | limoges
# Processing Record 38 of Set 9 | edd
# Processing Record 39 of Set 9 | walvis bay
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | trapani
# Processing Record 42 of Set 9 | hailar
# Processing Record 43 of Set 9 | camacupa
# Processing Record 44 of Set 9 | dondo
# Processing Record 45 of Set 9 | paldiski
# Processing Record 46 of Set 9 | mwinilunga
# Processing Record 47 of Set 9 | quelimane
# Processing Record 48 of Set 9 | margate
# Processing Record 49 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 9 | tautira
# Processing Record 1 of Set 10 | weligama
# Processing Record 2 of Set 10 | dicabisagan
# Processing Record 3 of Set 10 | bubaque
# Processing Record 4 of Set 10 | shitanjing
# Processing Record 5 of Set 10 | luganville
# Processing Record 6 of Set 10 | charagua
# Processing Record 7 of Set 10 | westport
# Processing Record 8 of Set 10 | siavonga
# Processing Record 9 of Set 10 | husavik
# Processing Record 10 of Set 10 | pavilosta
# Processing Record 11 of Set 10 | linares
# Processing Record 12 of Set 10 | tome-acu
# City not found. Skipping...
# Processing Record 13 of Set 10 | indi
# Processing Record 14 of Set 10 | vestmannaeyjar
# Processing Record 15 of Set 10 | merano
# Processing Record 16 of Set 10 | ambatofinandrahana
# Processing Record 17 of Set 10 | funadhoo
# Processing Record 18 of Set 10 | secunda
# Processing Record 19 of Set 10 | ketchikan
# Processing Record 20 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 10 | chepareria
# Processing Record 22 of Set 10 | makakilo city
# Processing Record 23 of Set 10 | bartlesville
# Processing Record 24 of Set 10 | at-bashi
# Processing Record 25 of Set 10 | znamenskoye
# Processing Record 26 of Set 10 | batagay-alyta
# Processing Record 27 of Set 10 | sambava
# Processing Record 28 of Set 10 | segezha
# Processing Record 29 of Set 10 | rio bueno
# Processing Record 30 of Set 10 | dryden
# Processing Record 31 of Set 10 | kattivakkam
# Processing Record 32 of Set 10 | trelew
# Processing Record 33 of Set 10 | waingapu
# Processing Record 34 of Set 10 | kyabe
# Processing Record 35 of Set 10 | chabahar
# Processing Record 36 of Set 10 | pochutla
# Processing Record 37 of Set 10 | pontypool
# Processing Record 38 of Set 10 | ngaoundere
# Processing Record 39 of Set 10 | puerto ayacucho
# Processing Record 40 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 10 | baykit
# Processing Record 42 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 10 | saint-augustin
# Processing Record 44 of Set 10 | gillette
# Processing Record 45 of Set 10 | bogashevo
# Processing Record 46 of Set 10 | sabang
# Processing Record 47 of Set 10 | shelburne
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | ballia
# Processing Record 50 of Set 10 | geraldton
# Processing Record 1 of Set 11 | berlevag
# Processing Record 2 of Set 11 | kununurra
# Processing Record 3 of Set 11 | herat
# Processing Record 4 of Set 11 | gold coast
# Processing Record 5 of Set 11 | mangai
# Processing Record 6 of Set 11 | ulagan
# Processing Record 7 of Set 11 | verkhnevilyuysk
# Processing Record 8 of Set 11 | pataias
# Processing Record 9 of Set 11 | puyang
# Processing Record 10 of Set 11 | omsukchan
# Processing Record 11 of Set 11 | masuguru
# Processing Record 12 of Set 11 | kloulklubed
# Processing Record 13 of Set 11 | qui nhon
# Processing Record 14 of Set 11 | denpasar
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | alofi
# Processing Record 18 of Set 11 | thinadhoo
# Processing Record 19 of Set 11 | krompachy
# Processing Record 20 of Set 11 | goderich
# Processing Record 21 of Set 11 | sao filipe
# Processing Record 22 of Set 11 | almeirim
# Processing Record 23 of Set 11 | north platte
# Processing Record 24 of Set 11 | bayevo
# Processing Record 25 of Set 11 | xudat
# Processing Record 26 of Set 11 | melo
# Processing Record 27 of Set 11 | hearst
# Processing Record 28 of Set 11 | uspenka
# Processing Record 29 of Set 11 | bonavista
# Processing Record 30 of Set 11 | hay river
# Processing Record 31 of Set 11 | hobyo
# Processing Record 32 of Set 11 | bonthe
# Processing Record 33 of Set 11 | ponta do sol
# Processing Record 34 of Set 11 | yarada
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 37 of Set 11 | goundam
# Processing Record 38 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 11 | kaitangata
# Processing Record 40 of Set 11 | stawell
# Processing Record 41 of Set 11 | koumac
# Processing Record 42 of Set 11 | kokopo
# Processing Record 43 of Set 11 | inverell
# Processing Record 44 of Set 11 | nemuro
# Processing Record 45 of Set 11 | janauba
# Processing Record 46 of Set 11 | freeport
# Processing Record 47 of Set 11 | lusaka
# Processing Record 48 of Set 11 | skjervoy
# Processing Record 49 of Set 11 | sorong
# Processing Record 50 of Set 11 | vestmanna
# Processing Record 1 of Set 12 | chicama
# Processing Record 2 of Set 12 | wasilla
# Processing Record 3 of Set 12 | richards bay
# Processing Record 4 of Set 12 | acajutla
# Processing Record 5 of Set 12 | korhogo
# Processing Record 6 of Set 12 | sitges
# Processing Record 7 of Set 12 | hambantota
# Processing Record 8 of Set 12 | coahuayana
# Processing Record 9 of Set 12 | amalapuram
# Processing Record 10 of Set 12 | inawashiro
# Processing Record 11 of Set 12 | acarau
# Processing Record 12 of Set 12 | pierre
# Processing Record 13 of Set 12 | puerto escondido
# Processing Record 14 of Set 12 | labuhan
# Processing Record 15 of Set 12 | lewisporte
# Processing Record 16 of Set 12 | abha
# Processing Record 17 of Set 12 | umea
# Processing Record 18 of Set 12 | mersing
# Processing Record 19 of Set 12 | parkersburg
# Processing Record 20 of Set 12 | ulaangom
# Processing Record 21 of Set 12 | lazaro cardenas
# Processing Record 22 of Set 12 | barabinsk
# Processing Record 23 of Set 12 | rabo de peixe
# Processing Record 24 of Set 12 | erdenet
# Processing Record 25 of Set 12 | tanta
# Processing Record 26 of Set 12 | pirgos
# Processing Record 27 of Set 12 | gizo
# Processing Record 28 of Set 12 | adrar
# Processing Record 29 of Set 12 | kamen
# Processing Record 30 of Set 12 | iquitos
# Processing Record 31 of Set 12 | nanyang
# Processing Record 32 of Set 12 | komsomolskiy
# Processing Record 33 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 12 | kalengwa
# Processing Record 35 of Set 12 | zdunska wola
# Processing Record 36 of Set 12 | kuala terengganu
# Processing Record 37 of Set 12 | resistencia
# Processing Record 38 of Set 12 | kharp
# Processing Record 39 of Set 12 | lebork
# Processing Record 40 of Set 12 | biloela
# Processing Record 41 of Set 12 | bandarbeyla
# Processing Record 42 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 12 | sirsa
# Processing Record 44 of Set 12 | marienburg
# Processing Record 45 of Set 12 | mbanza-ngungu
# Processing Record 46 of Set 12 | pasir gudang
# Processing Record 47 of Set 12 | hede
# Processing Record 48 of Set 12 | ngorongoro
# Processing Record 49 of Set 12 | charcas
# Processing Record 50 of Set 12 | dabat
# Processing Record 1 of Set 13 | tazovskiy
# Processing Record 2 of Set 13 | piacabucu
# Processing Record 3 of Set 13 | cabedelo
# Processing Record 4 of Set 13 | san quintin
# Processing Record 5 of Set 13 | baraboo
# Processing Record 6 of Set 13 | zaragoza
# Processing Record 7 of Set 13 | uruguaiana
# Processing Record 8 of Set 13 | miandrivazo
# Processing Record 9 of Set 13 | port augusta
# Processing Record 10 of Set 13 | andenes
# Processing Record 11 of Set 13 | solnechnyy
# Processing Record 12 of Set 13 | heishan
# Processing Record 13 of Set 13 | tucson
# Processing Record 14 of Set 13 | moncton
# Processing Record 15 of Set 13 | south venice
# Processing Record 16 of Set 13 | marystown
# Processing Record 17 of Set 13 | touros
# Processing Record 18 of Set 13 | bucarasica
# Processing Record 19 of Set 13 | jizan
# Processing Record 20 of Set 13 | pathalgaon
# Processing Record 21 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 22 of Set 13 | matara
# Processing Record 23 of Set 13 | paita
# Processing Record 24 of Set 13 | sibolga
# Processing Record 25 of Set 13 | nalut
# Processing Record 26 of Set 13 | tsovagyugh
# Processing Record 27 of Set 13 | kashmor
# Processing Record 28 of Set 13 | keta
# Processing Record 29 of Set 13 | springbok
# Processing Record 30 of Set 13 | saint george
# Processing Record 31 of Set 13 | madera
# Processing Record 32 of Set 13 | irvine
# Processing Record 33 of Set 13 | tyshkivka
# Processing Record 34 of Set 13 | naberera
# Processing Record 35 of Set 13 | rio grande
# Processing Record 36 of Set 13 | lakselv
# Processing Record 37 of Set 13 | rahimatpur
# Processing Record 38 of Set 13 | bridlington
# Processing Record 39 of Set 13 | ardrishaig
# Processing Record 40 of Set 13 | traverse city
# Processing Record 41 of Set 13 | cabra
# Processing Record 42 of Set 13 | pringsewu
# Processing Record 43 of Set 13 | senador jose porfirio
# Processing Record 44 of Set 13 | kalawit
# Processing Record 45 of Set 13 | balabac
# Processing Record 46 of Set 13 | praia
# Processing Record 47 of Set 13 | nishihara
# Processing Record 48 of Set 13 | banes
# Processing Record 49 of Set 13 | maniitsoq
# Processing Record 50 of Set 13 | roald
# Processing Record 1 of Set 14 | smithers
# Processing Record 2 of Set 14 | kempsey
# Processing Record 3 of Set 14 | takaka
# Processing Record 4 of Set 14 | port-gentil
# Processing Record 5 of Set 14 | isoka
# Processing Record 6 of Set 14 | surajgarh
# Processing Record 7 of Set 14 | sorrento
# Processing Record 8 of Set 14 | coihueco
# Processing Record 9 of Set 14 | kolochava
# Processing Record 10 of Set 14 | yuanping
# Processing Record 11 of Set 14 | hit
# Processing Record 12 of Set 14 | lahaina
# Processing Record 13 of Set 14 | washington
# Processing Record 14 of Set 14 | chapais
# Processing Record 15 of Set 14 | lardos
# Processing Record 16 of Set 14 | tashtyp
# Processing Record 17 of Set 14 | penzance
# Processing Record 18 of Set 14 | moorhead
# Processing Record 19 of Set 14 | griffith
# Processing Record 20 of Set 14 | alice springs
# Processing Record 21 of Set 14 | belaya glina
# Processing Record 22 of Set 14 | nisia floresta
# Processing Record 23 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 14 | gazanjyk
# Processing Record 25 of Set 14 | kasangulu
# Processing Record 26 of Set 14 | itarema
# Processing Record 27 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 14 | hoi an
# Processing Record 29 of Set 14 | yalutorovsk
# Processing Record 30 of Set 14 | kysyl-syr
# Processing Record 31 of Set 14 | ishigaki
# Processing Record 32 of Set 14 | jasdan
# Processing Record 33 of Set 14 | santiago de cao
# Processing Record 34 of Set 14 | portland
# Processing Record 35 of Set 14 | jablah
# Processing Record 36 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 14 | wanning
# Processing Record 38 of Set 14 | halden
# Processing Record 39 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 14 | jatibonico
# Processing Record 41 of Set 14 | panjab
# Processing Record 42 of Set 14 | shu
# Processing Record 43 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 14 | surt
# Processing Record 45 of Set 14 | khuzhir
# Processing Record 46 of Set 14 | kitimat
# Processing Record 47 of Set 14 | san francisco
# Processing Record 48 of Set 14 | bullhead city
# Processing Record 49 of Set 14 | macia
# Processing Record 50 of Set 14 | kamareddi
# Processing Record 1 of Set 15 | natal
# Processing Record 2 of Set 15 | harrisburg
# Processing Record 3 of Set 15 | safford
# Processing Record 4 of Set 15 | pemangkat
# Processing Record 5 of Set 15 | bulungu
# Processing Record 6 of Set 15 | erenhot
# Processing Record 7 of Set 15 | tanout
# Processing Record 8 of Set 15 | deputatskiy
# Processing Record 9 of Set 15 | tiruchchendur
# Processing Record 10 of Set 15 | sydney
# Processing Record 11 of Set 15 | constitucion
# Processing Record 12 of Set 15 | skagen
# Processing Record 13 of Set 15 | muzhi
# Processing Record 14 of Set 15 | plettenberg bay
# Processing Record 15 of Set 15 | olafsvik
# Processing Record 16 of Set 15 | sibu
# Processing Record 17 of Set 15 | rantepao
# Processing Record 18 of Set 15 | yerbogachen
# Processing Record 19 of Set 15 | camocim
# Processing Record 20 of Set 15 | mangrol
# Processing Record 21 of Set 15 | corner brook
# Processing Record 22 of Set 15 | cullinan
# Processing Record 23 of Set 15 | mitchell
# Processing Record 24 of Set 15 | koyilandi
# City not found. Skipping...
# Processing Record 25 of Set 15 | kamiiso
# Processing Record 26 of Set 15 | baijiantan
# Processing Record 27 of Set 15 | buchanan
# Processing Record 28 of Set 15 | tutoia
# Processing Record 29 of Set 15 | namatanai
# Processing Record 30 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 31 of Set 15 | burgos
# Processing Record 32 of Set 15 | tanabe
# Processing Record 33 of Set 15 | mayor pablo lagerenza
# Processing Record 34 of Set 15 | swellendam
# Processing Record 35 of Set 15 | saldanha
# Processing Record 36 of Set 15 | kungurtug
# Processing Record 37 of Set 15 | borogontsy
# Processing Record 38 of Set 15 | kenai
# Processing Record 39 of Set 15 | esso
# Processing Record 40 of Set 15 | cape canaveral
# Processing Record 41 of Set 15 | nnewi
# Processing Record 42 of Set 15 | velsk
# Processing Record 43 of Set 15 | suluq
# Processing Record 44 of Set 15 | jasper
# Processing Record 45 of Set 15 | cap-aux-meules
# Processing Record 46 of Set 15 | muros
# Processing Record 47 of Set 15 | manhattan
# Processing Record 48 of Set 15 | benxi
# Processing Record 49 of Set 15 | ucluelet
# Processing Record 50 of Set 15 | vanavara
# Processing Record 1 of Set 16 | ongandjera
# Processing Record 2 of Set 16 | katobu
# Processing Record 3 of Set 16 | volksrust
# Processing Record 4 of Set 16 | rabak
# Processing Record 5 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 16 | bilma
# Processing Record 8 of Set 16 | san juan
# Processing Record 9 of Set 16 | tamandare
# Processing Record 10 of Set 16 | karasburg
# Processing Record 11 of Set 16 | bongandanga
# Processing Record 12 of Set 16 | shache
# Processing Record 13 of Set 16 | okato
# Processing Record 14 of Set 16 | scarborough
# Processing Record 15 of Set 16 | kuito
# Processing Record 16 of Set 16 | cooma
# Processing Record 17 of Set 16 | burica
# City not found. Skipping...
# Processing Record 18 of Set 16 | dwarka
# Processing Record 19 of Set 16 | delitzsch
# Processing Record 20 of Set 16 | jawar
# Processing Record 21 of Set 16 | sorvag
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Dalbandin  28.8947   64.4101     47.01        30           0        4.54
# 1    Iqaluit  63.7506  -68.5145      2.93        65          75        3.00
# 2   Bengkulu  -3.8004  102.2655     78.73        78          79        2.80
# 3  Belomorsk  64.5232   34.7668     20.37        96         100        5.21
# 4      Tiksi  71.6872  128.8694    -18.17        99         100        2.26
# 5    Mataura -46.1927  168.8643     63.48        33          12        4.45
# 6   Cidreira -30.1811  -50.2056     71.55        91           1       13.87
# 7      Yumen  40.2833   97.2000     18.73        38           0       18.21
# 8    Rikitea -23.1203 -134.9692     77.92        75          65        7.58
# 9  Busselton -33.6500  115.3333     65.05        45         100        5.61
#
#   Country                 Date Current Condition
# 0      PK  2021-12-13 01:25:44         clear sky
# 1      CA  2021-12-13 01:25:44     broken clouds
# 2      ID  2021-12-13 01:25:45     broken clouds
# 3      RU  2021-12-13 01:25:45   overcast clouds
# 4      RU  2021-12-13 01:19:05   overcast clouds
# 5      NZ  2021-12-13 01:25:46        few clouds
# 6      BR  2021-12-13 01:25:46         clear sky
# 7      CN  2021-12-13 01:25:46         clear sky
# 8      PF  2021-12-13 01:25:47     broken clouds
# 9      AU  2021-12-13 01:25:47   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
